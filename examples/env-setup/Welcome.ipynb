# %% [markdown]
# **Welcome to CMPS460**

# %% [markdown]
# This course requires Python 3.12 or above:

# %%
import sys
print(sys.version_info)
assert sys.version_info >= (3, 12)
# Out:
# sys.version_info(major=3, minor=12, micro=12, releaselevel='final', serial=0)

# %% [markdown]
# Scikit-Learn ≥1.6 is required:

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %% [markdown]
# # Code example

# %%
print ("Welcome to CMPS460 - Machine Learning")
# Out:
# Welcome to CMPS460 - Machine Learning
